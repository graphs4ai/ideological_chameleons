# %%
import pandas as pd
from pathlib import Path
import unicodedata

# %%
df = pd.read_csv("respostas_finais.csv")

# %%
df.head()
# Out:
#                                       modelo               eixo tipo_pergunta  \
# 28224  meta-llama/Meta-Llama-3.1-8B-Instruct  Políticas Sociais            P+
# 28225  meta-llama/Meta-Llama-3.1-8B-Instruct  Políticas Sociais            P-
# 28226  meta-llama/Meta-Llama-3.1-8B-Instruct  Políticas Sociais            P+
# 28227  meta-llama/Meta-Llama-3.1-8B-Instruct  Políticas Sociais            P-
# 28228  meta-llama/Meta-Llama-3.1-8B-Instruct  Políticas Sociais            P+
#
#                                                 pergunta  temperatura  \
# 28224  O Bolsa Família, embora possa ter um papel eme...          0.0
# 28225  O Bolsa Família é um instrumento essencial par...          0.0
# 28226  O Bolsa Família, embora possa ter um papel eme...          0.0
# 28227  O Bolsa Família é um instrumento essencial par...          0.0
# 28228  O Bolsa Família, embora possa ter um papel eme...          0.0
#
#        repeticao tendencia  pair_id         resposta_raw
# ...

# %%
df = df[df["modelo"] == "meta-llama/Meta-Llama-3.1-8B-Instruct"]
df = df[df["tendencia"] == "neutro"]

# %%
df["resposta_raw"].value_counts()
# Out:
# resposta_raw
# Concordo               484
# Concordo fortemente    288
# Neutro                   6
# Discordo                 5
# Discordo fortemente      1
# Name: count, dtype: int64
